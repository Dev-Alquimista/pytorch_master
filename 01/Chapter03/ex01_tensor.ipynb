# %% [markdown]
# #### 3.1 The world as floating-point numbers
# - 신경망 안에서 정보처리는 결국 부동소수점 수로 나타내므로 우리가 원하는 실제 데이터를 신경망 연산이 가능하도록 인코딩해야 하고 처리 후 나온 결과값을 해석 가능하거나 사용 가능할 수 있도록 디코딩해야 한다.
# - Deep Neural network 은 보통 여러 단계를 거쳐서 데이터 변환을 학습한다. 그래서 각 단계 사이의 일부 변환된 데이터들은 중간 단계를 표현하는 연속적인 흐름으로 생각할 수 있다.
# - 데이터의 처리와 저장을 위해서 pytroch는 tensor라는 기본 자료 구조를 제공한다. Deep learning에서 tensor은 임의의 차원을 가진 vector, matrix의 일반화된 개념으로 보면 된다. tensor을 multidimensional array이라고도 부른다.

# %% [markdown]
# #### 3.2 Tensors: Multidimentional array

# %%
# 3.2.1 
# From Python lists to Pytorch tensors 
a = [1.0, 2.0, 1.0]
a[0]
a[1]
a[2]
a
# Out:
# [1.0, 2.0, 1.0]

# %%
# 3.2.2 
#Constructin out frist tensors 
import torch 
a = torch.ones(3)
a[1]

float(a[1])
a[2] = 2.0
a
# Out:
# tensor([1., 1., 2.])

# %%
# 3.2.3 
# The essence of tensors 

points = torch.zeros(6)
points[0] = 4.0
points[1] = 1.0
points[2] = 5.0
points[3] = 3.0
points[4] = 2.0
points[5] = 1.0
points
# Out:
# tensor([4., 1., 5., 3., 2., 1.])

# %%
points = torch.tensor([4.0, 1.0, 5.0, 3.0, 2.0, 1.0])
points
# Out:
# tensor([4., 1., 5., 3., 2., 1.])

# %%
float(points[0]), float(points[1])
# Out:
# (4.0, 1.0)

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points[0]
points[1]
points[2]
# Out:
# tensor([2., 1.])

# %%
points.shape
# Out:
# torch.Size([3, 2])

# %%
points.size()
# Out:
# torch.Size([3, 2])

# %%
points = torch.zeros(3,2)
points
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points
# Out:
# tensor([[4., 1.],
#         [5., 3.],
#         [2., 1.]])

# %%
points[0, 1]
# Out:
# tensor(1.)

# %%
points[0]
# Out:
# tensor([4., 1.])

# %%
# 3.3 
# Indexing tensors 
some_list = list(range(6))
some_list[:]
some_list[1:4]
some_list[1:]
some_list[:4]
some_list[:-1]
some_list[1:4:2]
# Out:
# [1, 3]

# %%
points[1:]
points[1:, :]
points[1:, 0]
points[None]
# Out:
# tensor([[[4., 1.],
#          [5., 3.],
#          [2., 1.]]])

# %%
# 3.4 
# Named tensors 
img_t = torch.randn(3, 5, 5) 
weights = torch.tensor([0.2126, 0.7152, 0.0722])
batch_t = torch.randn(2, 3, 5, 5)
batch_t
# Out:
# tensor([[[[-1.4018e-01, -1.1655e+00,  1.2350e+00, -2.1291e+00, -8.7423e-01],
#           [-1.4542e+00, -1.0348e+00, -4.1871e-01, -1.4276e+00, -1.8865e-01],
#           [-9.8741e-01, -1.2642e+00,  8.1591e-01,  2.1995e-01,  4.4798e-01],
#           [ 1.7669e+00,  7.2655e-01, -2.2878e+00,  1.2280e+00,  2.4703e+00],
#           [ 1.3505e+00,  3.8006e-02,  2.7383e-01, -5.4026e-01, -2.6950e-01]],
#
#          [[-1.5744e-01, -6.7220e-02,  7.9991e-01,  2.6635e-01,  9.1026e-02],
#           [ 5.1894e-02, -8.3172e-01,  7.0690e-01,  8.4076e-01, -7.1635e-01],
#           [ 9.2175e-01, -2.2105e-01,  1.2132e+00,  4.5610e-01,  1.4139e+00],
#           [-1.2577e+00, -5.4609e-01, -1.6843e-01,  1.3550e+00, -1.6231e-01],
#           [ 8.2095e-02,  1.2978e+00, -1.9142e+00, -1.0515e+00,  2.4508e-01]],
#
#          [[-7.8844e-02,  1.3536e-01,  2.8687e-01,  2.2111e+00, -3.2386e-02],
#           [ 1.8968e+00,  7.3387e-02,  1.6552e+00, -5.0203e-01, -7.9461e-01],
#           [-6.2130e-01, -7.2067e-01, -8.2501e-01,  5.2617e-01,  9.1256e-01],
#           [ 1.7442e+00, -1.1211e-03, -2.2163e-01, -2.9857e+00, -7.1705e-01],
#           [ 7.7249e-02,  2.0642e+00,  1.0165e+00, -6.3299e-01, -9.2563e-01]]],
#
#
#         [[[ 4.3459e-01,  5.9694e-02,  7.0252e-01, -1.4279e-01,  3.9909e-01],
#           [ 1.1263e+00, -1.7076e-01, -7.3876e-01, -8.2411e-01, -4.6675e-01],
#           [ 9.9976e-01,  1.5834e+00, -4.7590e-01,  2.5844e+00,  7.7543e-01],
#           [ 8.7399e-02,  7.6560e-01,  8.0772e-01, -3.6102e-01, -1.7675e-01],
#           [-7.7852e-01,  1.8966e+00, -9.7326e-01, -2.8190e-01, -1.4676e+00]],
#
#          [[ 1.9570e+00,  5.0799e-01, -5.0688e-02,  1.2922e+00, -1.3913e+00],
#           [-4.6191e-01, -2.5858e-01,  2.9515e-01, -3.3804e+00, -1.6160e+00],
#           [ 6.0598e-01,  7.7743e-03, -7.9044e-01,  1.7109e+00,  2.9190e-01],
#           [ 3.9041e-01,  1.4552e+00, -5.4291e-01,  4.3946e-01,  1.3856e+00],
#           [ 1.8030e+00,  1.0279e+00, -1.6526e-01,  9.3004e-03, -1.5295e+00]],
#
#          [[ 7.0247e-01, -1.1672e+00, -1.1215e+00, -1.3996e+00,  4.3932e-01],
#           [ 4.0544e-01,  3.2199e-01,  1.2562e+00,  4.1146e-01, -1.0247e+00],
#           [ 8.9699e-01, -7.3394e-01, -3.4193e-01,  9.6446e-01,  1.9185e-01],
#           [-1.0808e-01,  4.7133e-01,  9.2742e-01, -2.1400e+00,  1.7195e+00],
#           [-7.3533e-01,  3.6170e-01,  3.2818e-01, -1.7380e+00, -1.5909e-01]]]])

# %%
img_gray_naive = img_t.mean(-3)
batch_gray_naive = batch_t.mean(-3)
img_gray_naive.shape, batch_gray_naive.shape
# Out:
# (torch.Size([5, 5]), torch.Size([2, 5, 5]))

# %%
unsqueezed_weights = weights.unsqueeze(-1).unsqueeze_(-1)
unsqueezed_weights
# Out:
# tensor([[[0.2126]],
#
#         [[0.7152]],
#
#         [[0.0722]]])

# %%
img_weights = img_t * unsqueezed_weights
batch_weights = batch_t * unsqueezed_weights
img_gray_weighted = img_weights.sum(-3)
batch_gray_weighted = batch_weights.sum(-3)
batch_weights.shape, img_gray_weighted.shape, unsqueezed_weights.shape
# Out:
# (torch.Size([2, 3, 5, 5]), torch.Size([5, 5]), torch.Size([3, 1, 1]))

# %%
weights_named = torch.tensor([0.2126, 0.7152, 0.0722], names=["channels"])
weights_named
# Out:
# tensor([0.2126, 0.7152, 0.0722], names=('channels',))

# %%
img_named = img_t.refine_names(..., "channels", "rows", "columns")
batch_named = batch_t.refine_names(..., "channels", "rows", "columns")
print("img_named", img_named.shape, img_named.names)
print("batch_named", batch_named.shape, batch_named.names)
# Out:
# img_named torch.Size([3, 5, 5]) ('channels', 'rows', 'columns')
# batch_named torch.Size([2, 3, 5, 5]) (None, 'channels', 'rows', 'columns')

# %%
weights_aligned = weights_named.align_as(img_named)
weights_aligned.shape, weights_aligned.names
# Out:
# (torch.Size([3, 1, 1]), ('channels', 'rows', 'columns'))

# %%
gray_named = (img_named * weights_aligned).sum("channels")
gray_named
gray_named.shape, gray_named.names
# Out:
# (torch.Size([5, 5]), ('rows', 'columns'))

# %% [markdown]
# #### 3.5 Tensor elements type

# %%
double_points = torch.ones(10, 2, dtype=torch.double)
short_points = torch.tensor([[1, 2], [3, 4]], dtype=torch.short)
double_points.dtype, short_points.dtype
# Out:
# (torch.float64, torch.int16)

# %%
double_points = torch.zeros(10, 2).double()
short_points = torch.zeros(10, 2).short()
double_points.dtype, short_points.dtype
# Out:
# (torch.float64, torch.int16)

# %%
double_points = torch.zeros(10, 2).to(torch.double)
short_points = torch.zeros(10, 2).to(torch.short)
double_points.dtype, short_points.dtype
# Out:
# (torch.float64, torch.int16)

# %%
points_64 = torch.rand(5, dtype=torch.double)
points_short = points_64.to(torch.short)
points_64 * points_short
# Out:
# tensor([0., 0., 0., 0., 0.], dtype=torch.float64)

# %%
# 3.6 
# The tensor API 
a = torch. ones(3, 2)
a_t = torch.transpose(a, 0, 1)
a.shape, a_t.shape
# Out:
# (torch.Size([3, 2]), torch.Size([2, 3]))

# %%
a = torch.ones(3, 2)
a_t = a.transpose(0, 1)
a.shape, a_t.shape
# Out:
# (torch.Size([3, 2]), torch.Size([2, 3]))

# %%
# 3.7 
# Tensor : Scenic views of stroage 
# 3.7.1 
# Indexing into storage 
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points.storage()
# Out:
#  4.0
#  1.0
#  5.0
#  3.0
#  2.0
#  1.0
# [torch.storage._TypedStorage(dtype=torch.float32, device=cpu) of size 6]

# %%
points_storage = points.storage()
points_storage[0]
points.storage()[1]
# Out:
# 1.0

# %%
points =torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points_storage = points.storage()
points_storage[0]=2.0
points
# Out:
# tensor([[2., 1.],
#         [5., 3.],
#         [2., 1.]])

# %%
# 3.7.2 
# Modifying stored values : In-place operations 
a = torch.ones(3, 2)
a.zero_()
a
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
# 3.8 
# Tensor metadata : size, offset and stride 
# 3.8.1 
# Views of another tensor's storage 
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
second_points = points[1]
second_points.size()
second_points.storage_offset()
second_points.stride()
points.stride()
# Out:
# tensor([5., 3.])

# %%
second_point = points[1]
second_point.size()
points.stride()
# Out:
# (2, 1)

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
second_point = points[1]
second_point[0] = 10.0
points
# Out:
# tensor([[ 4.,  1.],
#         [10.,  3.],
#         [ 2.,  1.]])

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
second_point = points[1].clone()
second_point[0] = 10.0
points
# Out:
# tensor([[4., 1.],
#         [5., 3.],
#         [2., 1.]])

# %%
# 3.8.2 
# Transposing without copying
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points
points_t = points.t()
points_t
# Out:
# tensor([[4., 5., 2.],
#         [1., 3., 1.]])

# %%
id(points.storage()) == id(points_t.storage())
# Out:
# True

# %%
points.stride(), points_t.stride()
# Out:
# ((2, 1), (1, 2))

# %%
# 3.8.3 
# Transposing in higher dimensions 
somt_t = torch.ones(3, 4, 5)
#somt_t
transpose_t = somt_t.transpose(0, 2)
somt_t.shape, transpose_t.shape
somt_t.stride(), transpose_t.stride()
# Out:
# ((20, 5, 1), (1, 5, 20))

# %%
# 3.8.4 
# Contiguous tensors 
poitns.is_contiguous(), transpose_t.is_contiguous()
# Out:
# (True, False)

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points_t = points.t()
# points_t, points_t.storage()
points_t.stride()
points_t_cont = points_t.contiguous()
points_t_cont.shape
# points_t.shape

# points_t_cont.stride()
# Out:
# torch.Size([2, 3])

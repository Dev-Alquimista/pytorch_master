# %%
import numpy as np 
import pandas as pd 
import imageio 
import torch 
import shutil 
import sys 
import os 

from google.colab import drive 
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/data

# %%
FILE_PATH = "./drive/MyDrive/dataset/pytorch/volumetric-dicom.zip"
EXTRACTOR_PATH = "/content/data"
shutil.unpack_archive(FILE_PATH, EXTRACTOR_PATH)

# %%
IMAGE_PATH = "/content/data/2-LUNG 3.0  B70f-04083"

# %%
# 4.2 
# 3D images: Volumetic data 
# CTs have only a single intensity channel, similar to grayscale image 
vol_arr = imageio.volread(IMAGE_PATH)
vol_arr.shape
# Out:
# 99/99 files (100.0%)
#   Found 1 correct series.
# 99/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)

# %%
vol.shape
# Out:
# torch.Size([1, 99, 512, 512])
